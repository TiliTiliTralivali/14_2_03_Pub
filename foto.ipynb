# %% [markdown]
# Number 1

# %% [markdown]
# ![1614560341_16-p-ikonki-na-belom-fone-18.png](attachment:1614560341_16-p-ikonki-na-belom-fone-18.png)

# %% [markdown]
# Number 2

# %% [markdown]
# ![817a5acf77700c5f189851e8deacd22c.png](attachment:817a5acf77700c5f189851e8deacd22c.png)

# %% [markdown]
# Number 3

# %% [markdown]
# ![christianbale913201.jpg](attachment:christianbale913201.jpg)
